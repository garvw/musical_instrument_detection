# %%
# !pip install tensorflow scikit-learn
# Out:
# Requirement already satisfied: tensorflow in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (2.21.0)
# Requirement already satisfied: scikit-learn in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (1.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.33.0)
# Requirement already satisfied: setuptools in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.4.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: C:\Users\LEGION\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# !pip install tensorflow scikit-learn
# Out:
# Requirement already satisfied: tensorflow in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (2.21.0)
# Requirement already satisfied: scikit-learn in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (1.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.33.0)
# Requirement already satisfied: setuptools in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.4.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\legion\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: C:\Users\LEGION\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\LEGION\AppData\Local\Programs\Python\Python310\python.exe

# %%
# !C:\Users\LEGION\AppData\Local\Programs\Python\Python310\python.exe -m pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (0.11.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.15.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\legion\appdata\roaming\python\python310\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\legion\appdata\roaming\python\python310\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (2.2.6)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.64.0)
# Requirement already satisfied: joblib>=1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.7.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.5)
# Requirement already satisfied: packaging in c:\users\legion\appdata\roaming\python\python310\site-packages (from lazy_loader>=0.1->librosa) (26.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from pooch>=1.1->librosa) (2.33.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\legion\appdata\roaming\python\python310\site-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.6)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.2.25)
# [notice] A new release of pip available: 22.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import librosa
print("librosa working")
# Out:
# librosa working

# %%
import sys
# !{sys.executable} -m pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (0.11.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\legion\appdata\roaming\python\python310\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.15.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: numba>=0.51.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.64.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (2.2.6)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\legion\appdata\roaming\python\python310\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.7.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: joblib>=1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.5.3)
# Requirement already satisfied: pooch>=1.1 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.5)
# Requirement already satisfied: packaging in c:\users\legion\appdata\roaming\python\python310\site-packages (from lazy_loader>=0.1->librosa) (26.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from pooch>=1.1->librosa) (2.33.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\legion\appdata\roaming\python\python310\site-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (3.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.6)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.2.25)
# [notice] A new release of pip available: 22.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp310-cp310-win_amd64.whl (350.6 MB)
#      -------------------------------------- 350.6/350.6 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\legion\appdata\roaming\python\python310\site-packages (from tensorflow) (26.0)
# Collecting ml_dtypes<1.0.0,>=0.5.1
#   Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
#      -------------------------------------- 210.7/210.7 kB 6.5 MB/s eta 0:00:00
# Collecting google_pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.80.0-cp310-cp310-win_amd64.whl (4.9 MB)
#      ---------------------------------------- 4.9/4.9 MB 14.9 MB/s eta 0:00:00
# Collecting flatbuffers>=25.9.23
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\legion\appdata\roaming\python\python310\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.33.0)
# Collecting protobuf<8.0.0,>=6.31.1
#   Using cached protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-2.1.2-cp310-cp310-win_amd64.whl (60 kB)
#      ---------------------------------------- 60.3/60.3 kB ? eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in c:\users\legion\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting opt_einsum>=2.3.2
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Collecting keras>=3.12.0
#   Downloading keras-3.12.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.26.0 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.6)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Collecting h5py<3.15.0,>=3.11.0
#   Downloading h5py-3.14.0-cp310-cp310-win_amd64.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (63.2.0)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.46.3-py3-none-any.whl (30 kB)
# Collecting namex
#   Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting optree
#   Downloading optree-0.19.0-cp310-cp310-win_amd64.whl (321 kB)
#      ------------------------------------- 321.8/321.8 kB 10.0 MB/s eta 0:00:00
# Collecting rich
#   Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\legion\appdata\roaming\python\python310\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, termcolor, protobuf, optree, opt_einsum, ml_dtypes, mdurl, h5py, grpcio, google_pasta, gast, absl-py, markdown-it-py, astunparse, rich, keras, tensorflow
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 keras-3.12.1 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 protobuf-7.34.1 rich-14.3.3 tensorflow-2.21.0 termcolor-3.3.0 wheel-0.46.3 wrapt-2.1.2
# [notice] A new release of pip available: 22.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

import numpy as np
import librosa
import warnings
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

warnings.filterwarnings('ignore')

def extract_mel_spectrogram(y, sr):
    """
    Converts audio into a 2D image-like representation of frequencies over time.
    """
    # Create Mel-spectrogram
    mel_spec = librosa.feature.melspectrogram(
        y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128
    )
    # Convert to decibels (log scale, how humans hear)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    
    return mel_spec_db

print("Deep Learning Setup complete. Spectrogram extractor ready.")
# Out:
# Deep Learning Setup complete. Spectrogram extractor ready.

# %%
X = []
y_labels = []

data_path = r"E:\ml-instrument detection\data\IRMAS-TrainingData"
window_duration = 1.0  
target_sr = 22050

print("Processing training data into Spectrograms... this will take a few minutes.")

for instrument in os.listdir(data_path):
    folder = os.path.join(data_path, instrument)
    if not os.path.isdir(folder): continue
        
    for file in os.listdir(folder):
        if not file.endswith(".wav"): continue
        
        file_path = os.path.join(folder, file)
        
        try:
            audio, sr = librosa.load(file_path, sr=target_sr)
            samples_per_window = int(window_duration * target_sr)
            
            for i in range(0, len(audio), samples_per_window):
                window = audio[i : i + samples_per_window]
                
                # Pad with zeros if the chunk is slightly too short
                if len(window) < samples_per_window:
                    window = np.pad(window, (0, samples_per_window - len(window)))
                
                spectrogram = extract_mel_spectrogram(window, target_sr)
                
                # Ensure uniform shape (128 mels x 44 time frames for 1 sec)
                if spectrogram.shape[1] == 44: 
                    X.append(spectrogram)
                    y_labels.append(instrument)

        except Exception as e:
            pass 

X = np.array(X)
y_labels = np.array(y_labels)

# Reshape X to add a "color channel" dimension required by CNNs: (Samples, Height, Width, Channels)
X = X[..., np.newaxis] 

# Convert text labels ('gac', 'pia') into integer categories (0, 1, 2...)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_labels)
y_categorical = to_categorical(y_encoded)

print(f"Dataset shape for CNN: {X.shape}")
print("Classes identified:", label_encoder.classes_)
# Out:
# Processing training data into Spectrograms... this will take a few minutes.
# Dataset shape for CNN: (17302, 128, 44, 1)
# Classes identified: ['dru' 'flu' 'gac' 'gel' 'pia' 'sax' 'tru' 'vio' 'voi']

# %%
# 1. Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X, y_categorical, test_size=0.2, random_state=42, stratify=y_categorical
)

input_shape = X_train.shape[1:] # Should be (128, 44, 1)
num_classes = len(label_encoder.classes_)

# 2. Build the Convolutional Neural Network (CNN)
model = models.Sequential([
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.BatchNormalization(),
    
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.BatchNormalization(),
    
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.BatchNormalization(),
    
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5), # Prevents overfitting
    layers.Dense(num_classes, activation='softmax') # Outputs probabilities
])

model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Stop training early if validation accuracy stops improving
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', patience=5, restore_best_weights=True
)

print("Training CNN Model...")
history = model.fit(
    X_train, y_train, 
    epochs=30, 
    batch_size=32, 
    validation_data=(X_test, y_test),
    callbacks=[early_stopping]
)

# 4. Evaluate
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nFinal CNN Validation Accuracy: {test_acc:.4f}")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Training CNN Model...
# Epoch 1/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 44s 96ms/step - accuracy: 0.3866 - loss: 1.8003 - val_accuracy: 0.4322 - val_loss: 1.6237
# Epoch 2/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.4831 - loss: 1.4664 - val_accuracy: 0.4285 - val_loss: 1.8207
# Epoch 3/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - accuracy: 0.5519 - loss: 1.2712 - val_accuracy: 0.5415 - val_loss: 1.5060
# Epoch 4/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.5945 - loss: 1.1645 - val_accuracy: 0.3282 - val_loss: 4.0253
# Epoch 5/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - accuracy: 0.6351 - loss: 1.0387 - val_accuracy: 0.5548 - val_loss: 1.4135
# Epoch 6/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 42s 98ms/step - accuracy: 0.6671 - loss: 0.9490 - val_accuracy: 0.6267 - val_loss: 1.1149
# Epoch 7/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 42s 98ms/step - accuracy: 0.7095 - loss: 0.8423 - val_accuracy: 0.6180 - val_loss: 1.1060
# Epoch 8/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 43s 99ms/step - accuracy: 0.7343 - loss: 0.7485 - val_accuracy: 0.5987 - val_loss: 1.2565
# Epoch 9/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - accuracy: 0.7708 - loss: 0.6484 - val_accuracy: 0.5160 - val_loss: 1.8431
# Epoch 10/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 44s 102ms/step - accuracy: 0.7965 - loss: 0.5787 - val_accuracy: 0.6712 - val_loss: 1.1843
# Epoch 11/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.8147 - loss: 0.5245 - val_accuracy: 0.7038 - val_loss: 1.0392
# Epoch 12/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.8343 - loss: 0.4812 - val_accuracy: 0.6680 - val_loss: 1.0693
# Epoch 13/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 43s 98ms/step - accuracy: 0.8524 - loss: 0.4119 - val_accuracy: 0.7140 - val_loss: 0.9618
# Epoch 14/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 43s 99ms/step - accuracy: 0.8705 - loss: 0.3733 - val_accuracy: 0.6186 - val_loss: 1.7963
# Epoch 15/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - accuracy: 0.8740 - loss: 0.3591 - val_accuracy: 0.6513 - val_loss: 1.4046
# Epoch 16/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.8859 - loss: 0.3168 - val_accuracy: 0.6721 - val_loss: 1.4353
# Epoch 17/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 44s 102ms/step - accuracy: 0.8986 - loss: 0.2889 - val_accuracy: 0.5267 - val_loss: 2.6896
# Epoch 18/30
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.9038 - loss: 0.2674 - val_accuracy: 0.6978 - val_loss: 1.2183
#
# Final CNN Validation Accuracy: 0.7140

# %%
import math
import numpy as np
import librosa
from collections import Counter

test_file = "test.wav"
print(f"Analyzing {test_file} with Deep Learning (Excluding 'gel')...\n")

audio_test, sr_test = librosa.load(test_file, sr=22050)

window_size_sec = 1.0  
hop_size_sec = 0.5     

samples_per_window = int(window_size_sec * sr_test)
hop_length_samples = int(hop_size_sec * sr_test)

time_templates = []
vote_threshold = 0.40 

for start_sample in range(0, len(audio_test) - samples_per_window, hop_length_samples):
    end_sample = start_sample + samples_per_window
    window = audio_test[start_sample:end_sample]
    
    if len(window) < samples_per_window:
        window = np.pad(window, (0, samples_per_window - len(window)))
        
    start_time = start_sample / sr_test
    end_time = end_sample / sr_test
    
    # Extract spectrogram and shape it for the CNN: (1, 128, 44, 1)
    spectrogram = extract_mel_spectrogram(window, sr_test)
    if spectrogram.shape[1] != 44: continue
    
    features_cnn = spectrogram[np.newaxis, ..., np.newaxis] 
    
    # Get all probabilities for this specific 1-second window
    probabilities = model.predict(features_cnn, verbose=0)[0]
    
    # Sort the predictions from highest probability to lowest
    top_indices = np.argsort(probabilities)[::-1]
    
    # Identify the absolute best guess
    best_idx = top_indices[0]
    predicted_instrument = label_encoder.inverse_transform([best_idx])[0]
    confidence = probabilities[best_idx]
    
    # --- NEW EXCLUSION LOGIC ---
    # If the top guess is 'gel', fallback to the second-best guess
    #if predicted_instrument == 'gel':
      #  second_best_idx = top_indices[1]
     #   predicted_instrument = label_encoder.inverse_transform([second_best_idx])[0]
     #   confidence = probabilities[second_best_idx] # Use the lower confidence of the runner-up
    
    # Only record if the model meets the threshold
    if confidence > vote_threshold:
        time_templates.append({
            "start": round(start_time, 1),
            "end": round(end_time, 1),
            "instrument": predicted_instrument,
            "confidence": round(confidence, 2)
        })

# print("--- FINE-GRAINED DETECTION ---")
# for t in time_templates:
#     print(f"[{t['start']}s - {t['end']}s] : {t['instrument'].upper()} (Conf: {t['confidence']})")

print("\n--- 10-SECOND BLOCK SUMMARIES ---")
total_duration = len(audio_test) / sr_test
block_size = 5.0

for block_start in range(0, math.ceil(total_duration), int(block_size)):
    block_end = block_start + block_size
    
    # Gather all valid predictions (keeping the whole dictionary to access confidence)
    valid_predictions = [
        t for t in time_templates
        if block_start <= t['start'] < block_end
    ]
    
    if valid_predictions:
        # Dictionary to store both the count and the accumulated confidence
        stats = {}
        for p in valid_predictions:
            inst = p['instrument']
            if inst not in stats:
                stats[inst] = {'count': 0, 'total_conf': 0.0}
            
            stats[inst]['count'] += 1
            stats[inst]['total_conf'] += p['confidence']
            
        # Sort the instruments: FIRST by count (highest to lowest), THEN by total_conf (highest to lowest)
        sorted_stats = sorted(
            stats.items(), 
            key=lambda item: (item[1]['count'], item[1]['total_conf']), 
            reverse=True
        )
        
        # The winner is now guaranteed to be the first item in the sorted list
        top_instrument = sorted_stats[0][0]
        top_count = sorted_stats[0][1]['count']
        
        print(f"[{int(block_start):02d}s - {int(block_end):02d}s] : {top_instrument.upper()} (Detected {top_count} times)")
    else:
        print(f"[{int(block_start):02d}s - {int(block_end):02d}s] : NO CLEAR INSTRUMENT")
# Out:
# Analyzing test.wav with Deep Learning (Excluding 'gel')...
#
#
# --- 10-SECOND BLOCK SUMMARIES ---
# [00s - 05s] : PIA (Detected 9 times)
# [05s - 10s] : PIA (Detected 10 times)
# [10s - 15s] : VOI (Detected 5 times)
# [15s - 20s] : VOI (Detected 10 times)
# [20s - 25s] : VOI (Detected 10 times)
# [25s - 30s] : VOI (Detected 10 times)
# [30s - 35s] : VOI (Detected 10 times)
# [35s - 40s] : VOI (Detected 9 times)
# [40s - 45s] : VOI (Detected 10 times)
# [45s - 50s] : VOI (Detected 8 times)
# [50s - 55s] : SAX (Detected 6 times)
# [55s - 60s] : SAX (Detected 9 times)
# [60s - 65s] : SAX (Detected 8 times)
# [65s - 70s] : VIO (Detected 7 times)
# [70s - 75s] : TRU (Detected 7 times)
# [75s - 80s] : SAX (Detected 8 times)
# [80s - 85s] : SAX (Detected 4 times)
# [85s - 90s] : SAX (Detected 6 times)
# [90s - 95s] : GEL (Detected 7 times)
# [95s - 100s] : GAC (Detected 3 times)
# [100s - 105s] : GAC (Detected 10 times)
# [105s - 110s] : VOI (Detected 4 times)
# [110s - 115s] : FLU (Detected 7 times)
# [115s - 120s] : FLU (Detected 9 times)
# [120s - 125s] : DRU (Detected 10 times)
# [125s - 130s] : DRU (Detected 10 times)
# [130s - 135s] : DRU (Detected 3 times)
